# %% [markdown]
# <a href="https://colab.research.google.com/github/timberking2/ML_magistr/blob/main/%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D0%BA%D0%B0_1_%D0%9C%D0%B0%D1%88%D0%B8%D0%BD%D0%BA%D0%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # МЛ Практика 1
# ## Обзор занятий: Чем предстоит заниматься
# Цели сессии:
#
# 1. Ознакомление с основными понятиями машинного обучения и структурой практических занятий.
# 2. Представление доступных наборов данных для последующих упражнений.
# 3. Формирование списка участников и распределение ролей (при необходимости).
# 4. Практическое освоение методов описательного анализа данных.
# 5. Понимание типов данных и их важности в контексте машинного обучения.
# План занятий:
#
# 1. Введение и обзор целей курса.
# 2. Представление наборов данных.
# 3. Формирование списка студентов.
# 4. Совместный разбор выбранного набора данных с обсуждением вопросов.
# 5. Задача 1: Описание набора данных и определение типов данных.
# 6. Пример статистического разбора на основе wine.csv.
# 7. Обсуждение типов переменных и их определения по статистике.
# 8. Вопросы и ответы, обсуждение домашних заданий.

# %% [markdown]
# # Наборы данных по вариантам

# %% [markdown]
# Примеры наборов данных

# %% [markdown]
# 7. https://www.kaggle.com/datasets/uciml/student-alcohol-consumption

# %% [markdown]
# ## Описание:
# В этом разделе вы загрузите набор данных wine.csv, ознакомитесь с его структурой и проведёте первичный обзор.

# %%
# установка зависимостей
# !pip install pandas matplotlib seaborn

# %%
# импортируем библиотеки
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Описание:
# В этом разделе вы загрузите набор данных wine.csv, ознакомитесь с его структурой и проведёте первичный обзор.

# %%
PATH_TO_FILE: str = '/content/student-mat.csv' # Загрузка набора данных (ДОБАВИЛ ФАЙЛ)
## p.s. в левой панеле нажать на папку и перетащить туда файл,
## а wince.csv заменить на свой вариант (ПКМ -> копировать путь)

df = pd.read_csv(PATH_TO_FILE) # функция превращение данных из CSV в DataFrame

# %%
# вывод датафрейма
df # p.s. обычно переменную с набором данных называют df, придерживайтесь этого наименования в дальнейшем
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
# Вывод первых 5 строк
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
# вывод 5 последних строк
df.tail()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 390  ...      5        5      4     4     5      4       11   9   9   9
# 391  ...      2        4      5     3     4      2        3  14  16  16
# 392  ...      5        5      3     3     3      3        3  10   8   7
# 393  ...      4        4      1     3     4      5        0  11  12  10
# 394  ...      3        2      3     3     3      5        5   8   9   9
#
# [5 rows x 33 columns]

# %%
# Информация о наборе данных
df.info() # инфо о датасете название колонки, сколько не пропущенных, дефолтный тип данных
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %%
# Статистический разбор
df.describe() # include=all (вывод включая категориальные)
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
# преобразование в категориальные
# df.columnName = df.columnName.astype('category')
# or
# df['column Name'] = df['column Name'].astype('category')


df['school'] = df['school'].astype('category')
df['sex'] = df['sex'].astype('category')
df['age'] = df['age'].astype('int')
df['address'] = df['address'].astype('category')
df['famsize'] = df['famsize'].astype('category')
df['Pstatus'] = df['Pstatus'].astype('category')
df['Medu'] = df['Medu'].astype('int')
df['Fedu'] = df['Fedu'].astype('int')
df['Mjob'] = df['Mjob'].astype('category')
df['Fjob'] = df['Fjob'].astype('category')
df['reason'] = df['reason'].astype('category')
df['guardian'] = df['guardian'].astype('category')
df['traveltime'] = df['traveltime'].astype('int')
df['studytime'] = df['studytime'].astype('int')
df['failures'] = df['failures'].astype('int')
df['schoolsup'] = df['schoolsup'].astype('category')
df['famsup'] = df['famsup'].astype('category')
df['paid'] = df['paid'].astype('category')
df['activities'] = df['activities'].astype('category')
df['nursery'] = df['nursery'].astype('category')
df['higher'] = df['higher'].astype('category')
df['internet'] = df['internet'].astype('category')
df['romantic'] = df['romantic'].astype('category')
df['famrel'] = df['famrel'].astype('int')
df['freetime'] = df['freetime'].astype('int')
df['goout'] = df['goout'].astype('int')
df['Dalc'] = df['Dalc'].astype('int')
df['Walc'] = df['Walc'].astype('int')
df['health'] = df['health'].astype('int')
df['absences'] = df['absences'].astype('int')
df['G1'] = df['G1'].astype('int')
df['G2'] = df['G2'].astype('int')
df['G3'] = df['G3'].astype('int')

# %%
# Вывод колонок в наборе данных
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %% [markdown]
# ## Определение типов переменных

# %%
# Список столбцов и их типов данных
print(df.dtypes)
# Out:
# school        category
# sex           category
# age              int64
# address       category
# famsize       category
# Pstatus       category
# Medu             int64
# Fedu             int64
# Mjob          category
# Fjob          category
# reason        category
# guardian      category
# traveltime       int64
# studytime        int64
# failures         int64
# schoolsup     category
# famsup        category
# paid          category
# activities    category
# nursery       category
# higher        category
# internet      category
# romantic      category
# famrel           int64
# freetime         int64
# goout            int64
# Dalc             int64
# Walc             int64
# health           int64
# absences         int64
# G1               int64
# G2               int64
# G3               int64
# dtype: object

# %% [markdown]
# - Числовые переменные обычно имеют тип int64 или float64.
# - Категориальные переменные могут иметь тип object или int (например метки класса)

# %% [markdown]
# ## Статистический разбор данных

# %% [markdown]
# 1. **Посчитайте количество уникальных значений для каждой переменной:**

# %%
# Количество уникальных значений
for column in df.columns:
    print(f'{column}: {df[column].nunique()} уникальных значений')
# Out:
# school: 2 уникальных значений
# sex: 2 уникальных значений
# age: 8 уникальных значений
# address: 2 уникальных значений
# famsize: 2 уникальных значений
# Pstatus: 2 уникальных значений
# Medu: 5 уникальных значений
# Fedu: 5 уникальных значений
# Mjob: 5 уникальных значений
# Fjob: 5 уникальных значений
# reason: 4 уникальных значений
# guardian: 3 уникальных значений
# traveltime: 4 уникальных значений
# studytime: 4 уникальных значений
# failures: 4 уникальных значений
# schoolsup: 2 уникальных значений
# famsup: 2 уникальных значений
# paid: 2 уникальных значений
# activities: 2 уникальных значений
# nursery: 2 уникальных значений
# higher: 2 уникальных значений
# internet: 2 уникальных значений
# romantic: 2 уникальных значений
# famrel: 5 уникальных значений
# freetime: 5 уникальных значений
# goout: 5 уникальных значений
# Dalc: 5 уникальных значений
# Walc: 5 уникальных значений
# health: 5 уникальных значений
# absences: 34 уникальных значений
# G1: 17 уникальных значений
# ...

# %% [markdown]
# **⏰ задача**
#
# Определить типы переменных
# - номинальные переменные (не имеют порядка и сравнения)
# - порядковые пиеременные (имеют порядок, но не имеют смысла мат операции)
# - числовые непрерывные переменные (имеют порядок, есть смысл мат операций)
#
# Вывести статистику для числовых и для категоиральных перменных раздельно.
#
# p.s. если существует несколько гипотез к какому типу относительно одна и та же переменной - объяснить почему

# %% [markdown]
# | Название переменной | Тип переменной | Описание |
# |-------------------|---------------|----------|
# | school | Номинальная | Название школы (GP или MS) |
# | sex | Номинальная | Пол студента (F или M) |
# | age | Числовая непрерывная | Возраст в годах |
# | address | Номинальная | Тип адреса (U - городской, R - сельский) |
# | famsize | Номинальная | Размер семьи (LE3 - ≤3, GT3 - >3) |
# | Pstatus | Номинальная | Статус проживания родителей (T - вместе, A - раздельно) |
# | Medu | Порядковая | Образование матери (0-4) |
# | Fedu | Порядковая | Образование отца (0-4) |
# | Mjob | Номинальная | Профессия матери |
# | Fjob | Номинальная | Профессия отца |
# | reason | Номинальная | Причина выбора школы |
# | guardian | Номинальная | Опекун студента |
# | traveltime | Порядковая | Время в пути до школы (1-4) |
# | studytime | Порядковая | Время на учебу (1-4) |
# | failures | Порядковая | Количество прошлых неудач |
# | schoolsup | Номинальная | Дополнительная образовательная поддержка |
# | famsup | Номинальная | Семейная образовательная поддержка |
# | paid | Номинальная | Платные занятия по предмету |
# | activities | Номинальная | Внеклассные мероприятия |
# | nursery | Номинальная | Посещал детский сад |
# | higher | Номинальная | Хочет получить высшее образование |
# | internet | Номинальная | Наличие интернета дома |
# | romantic | Номинальная | В романтических отношениях |
# | famrel | Порядковая | Качество семейных отношений (1-5) |
# | freetime | Порядковая | Свободное время после школы (1-5) |
# | goout | Порядковая | Время с друзьями (1-5) |
# | Dalc | Порядковая | Употребление алкоголя в рабочие дни (1-5) |
# | Walc | Порядковая | Употребление алкоголя в выходные (1-5) |
# | health | Порядковая | Состояние здоровья (1-5) |
# | absences | Числовая непрерывная | Количество пропусков занятий |
# | G1 | Числовая непрерывная | Оценка за первый период |
# | G2 | Числовая непрерывная | Оценка за второй период |
# | G3 | Числовая непрерывная | Итоговая оценка |

# %%
# Числовые переменные
print("ЧИСЛОВЫЕ ПЕРЕМЕННЫЕ:")
print(df[['age', 'absences', 'G1', 'G2', 'G3']].describe())
# Out:
# ЧИСЛОВЫЕ ПЕРЕМЕННЫЕ:
#               age    absences          G1          G2          G3
# count  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    5.708861   10.908861   10.713924   10.415190
# std      1.276043    8.003096    3.319195    3.761505    4.581443
# min     15.000000    0.000000    3.000000    0.000000    0.000000
# 25%     16.000000    0.000000    8.000000    9.000000    8.000000
# 50%     17.000000    4.000000   11.000000   11.000000   11.000000
# 75%     18.000000    8.000000   13.000000   13.000000   14.000000
# max     22.000000   75.000000   19.000000   19.000000   20.000000

# %%
print("\nКАТЕГОРИАЛЬНЫЕ ПЕРЕМЕННЫЕ:")
for col in df.columns:
    if df[col].dtype == 'object' or df[col].nunique() < 10:
        print(f"\n{col}:")
        print(df[col].value_counts())
# Out:
# КАТЕГОРИАЛЬНЫЕ ПЕРЕМЕННЫЕ:
#
# school:
# school
# GP    349
# MS     46
# Name: count, dtype: int64
#
# sex:
# sex
# F    208
# M    187
# Name: count, dtype: int64
#
# age:
# age
# 16    104
# 17     98
# 18     82
# 15     82
# 19     24
# 20      3
# 22      1
# 21      1
# Name: count, dtype: int64
#
# address:
# address
# U    307
# R     88
# Name: count, dtype: int64
#
# famsize:
# famsize
# GT3    281
# LE3    114
# Name: count, dtype: int64
#
# Pstatus:
# Pstatus
# T    354
# A     41
# Name: count, dtype: int64
#
# Medu:
# Medu
# 4    131
# 2    103
# 3     99
# 1     59
# 0      3
# Name: count, dtype: int64
#
# Fedu:
# Fedu
# 2    115
# 3    100
# 4     96
# 1     82
# 0      2
# Name: count, dtype: int64
#
# Mjob:
# Mjob
# other       141
# services    103
# at_home      59
# teacher      58
# health       34
# Name: count, dtype: int64
#
# Fjob:
# Fjob
# other       217
# services    111
# teacher      29
# at_home      20
# health       18
# Name: count, dtype: int64
# ...

# %% [markdown]
# Гипотезы:
# Переменная failures (Количество неудач)
# Гипотеза 1: Числовая дискретная (счетчик)
# Гипотеза 2: Порядковая (шкала уровня проблем)
#
# Я выбрал: Порядковая - верхняя категория "3" означает "3 и более"
#
# Переменные G1, G2, G3 (Оценки)
# Гипотеза 1: Порядковая (баллы как ранги)
# Гипотеза 2: Числовая непрерывная (для статистического анализа)
#
# Я выбрал: Числовая непрерывная - стандартный подход в образовательной статистике (нейронки подмогли чуток)

# %% [markdown]
# ## **4. Визуализация распределения переменных**
#
# ### **Описание:**
# Создайте визуализации для понимания распределения числовых и категориальных переменных.
#
# ### **Шаги:**

# %% [markdown]
# 1. **Гистограмма для числовых переменных:**

# %%
# Возраст взят как пример
sns.histplot(df['age'], kde=True) # взрослы курить пить круто ыыыы
plt.title('Распределение Age')
plt.xlabel('Age')
plt.ylabel('Частота')
plt.show()

# %%
# ниже код для крутых
num_cols = df.select_dtypes(include=['int64', 'float64']).columns
num_cols = ['age', 'absences', 'G1', 'G2', 'G3']  # явно указываем числовые колонки из датасета, потом плачем чтоб всё заработало

fig, axes = plt.subplots(1, len(num_cols), figsize=(6 * len(num_cols), 4))

for ax, col in zip(axes, num_cols):
    sns.histplot(df[col], kde=True, ax=ax)
    ax.set_title(f'Распределение {col}')
    ax.set_xlabel(col)
    ax.set_ylabel('Частота')

plt.tight_layout() # то ещё tight дело
plt.show()

# %% [markdown]
# **задача ⏰**
#
# Описать вывод графиков.
# - Является ли распределение нормальным или отлично от него?
# - Концентрация большинства значений
# - если есть категориальная переменная, то с помощью параметры hue попробовать предсказать значение категориальный переменной (пример с диоксидом серы и типом вина)
#
# p.s. 3-5 самых показательных примеров.

# %%
# Теперь можно использовать category потому шо я пофиксил
# Выбираем все категориальные переменные
cat_cols = df.select_dtypes(include=['category']).columns
n_cols = 3
n_rows = (len(cat_cols) + n_cols - 1) // n_cols
fig, axes = plt.subplots(n_rows, n_cols, figsize=(15, 6 * n_rows))
axes = axes.flatten()

for ax, col in zip(axes, cat_cols):
    sns.countplot(data=df, x=col, hue=col, ax=ax)  # Добавил hue=col (v12 наверно, или уже 13, короче час на смарку)
    ax.set_title(f'Распределение {col}')
    ax.set_xlabel(col)
    ax.set_ylabel('Количество')
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right') #hahaha got you
    ax.legend().remove()
for i in range(len(cat_cols), len(axes)):
    axes[i].set_visible(False)

plt.tight_layout()
plt.show()

# правда я не уверен в правильности выполнения (пушто все взял), потом переделаю на крайняк
# Out:
# /tmp/ipython-input-3549504525.py:14: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right') #hahaha got you
# /tmp/ipython-input-3549504525.py:15: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend().remove()
# /tmp/ipython-input-3549504525.py:14: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right') #hahaha got you
# /tmp/ipython-input-3549504525.py:15: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend().remove()
# ...

# %%
# Распределение возраста с перебивкой по bring me the horizon

# sns.histplot(df, x='age', hue='sex', kde=True, multiple='layer')
# plt.title('Предсказание пола по возрасту')
# plt.xlabel('Age')
# plt.ylabel('Частота')
# plt.show()

# %% [markdown]
# Категориальные переменные распределены неравномерно, там куча перекосов в общем, вооооот
#
# У Ярика подрезал идею о чем-то интересном, потому внимание!
#
# 1 - Нет четкой корреляции между количеством пропусков и оценками, ленивые студенты (как я) даже с тонной пропусков имеют столько же баллов
#
# 2 - Если я правильно понял, то если мать студента умная, с корочкой крутой и так далее, то он тоже умный
#
# 3 - Деревенские менее крутые чем городские (у них меньше баллы)
#
# 4 - Чем больше у студентов оценки, тем больше они хотят высшее образование, такая вот штука
#
# 5 - Я устал босс ![157462813113401882.png](data:image/png;base64,...)

# %% [markdown]
# **задача ⏰**
#
# Описать вывод графиков.
# - в каких значениях концентрируентся переменная?
# - если есть категориальная переменная, то с помощью параметры hue попробовать предсказать значение категориальный переменной (пример с диоксидом серы и типом вина)

# %% [markdown]
# **Боксплот для числовой переменной:**

# %%
sns.boxplot(x=df['absences'])
plt.title('Boxplot Absences')
plt.xlabel('Absences')
plt.show()
#num_cols = df.select_dtypes(include='float').columns # если есть int чиловая переменная либо + ['col1', 'col2'], либо такие колонки преобразовать во flaot
#fig, axes = plt.subplots(1, len(num_cols), figsize=(6 * len(num_cols), 4))

#for ax, col in zip(axes, num_cols):
#    sns.boxplot(df[col], ax=ax)
#    ax.set_title(f'Распределение {col}')
#    ax.set_xlabel(col)
#    ax.set_ylabel('Частота')

#plt.tight_layout()
#plt.show()

# %% [markdown]
# Большинство студентов имеют 0-8 пропусков, что в целом база

# %% [markdown]
# **задача ⏰**
#
# Описать вывод графиков.
# - Есть ли выбросы?
# - если есть категориальная переменная, то с помощью параметры hue попробовать предсказать значение категориальный переменной (пример с диоксидом серы и типом вина). Определить различия по медиане

# %% [markdown]
# Наличие множества выбросов в правой части графика показывает, что есть группа студентов с аномально высоким количеством пропусков (более 16), что автоматически относит их в список на отчисление (аномалия)

# %% [markdown]
# **Постройте "! КРАСИВУЮ !" корреляционную матрицу для всех числовых переменных и визуализируйте её с помощью тепловой карты:**

# %%
# # Корреляционная матрица
# correlation_matrix = df.corr()

# # Визуализация тепловой карты
# sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
# plt.title('Корреляционная матрица')
# plt.show()


# Все, что не инт в помойку
numeric_cols = df.select_dtypes(include=['int64']).columns

# Нео в матрице
corr_matrix = df[numeric_cols].corr()

# Визуализация тепловой карты
plt.figure(figsize=(14, 10))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', center=0,
           square=True, fmt='.2f', linewidths=0.5)
plt.title('Корреляционная матрица', fontsize=16, pad=20)
plt.tight_layout()
plt.show()

# %% [markdown]
# **если ValueError**

# %% [markdown]
# Ошибок не обнаружено ☹

# %%
# Если будут ошибки ValueError из-за could not conver string to float
df = df.drop('colName', axis=1)
# найти колонку, из-за которой ничего не получается,
# можно найти по object из df.info()

# %% [markdown]
# **задача ⏰**
#
# Интерпертировать полученный результат:
# - Какие переменные не коррелируют?
# - Какие переменные имеют сильную положительную корреляцию?
# - Какие переменные имеют сильную слабую корреляцию?
#
# p.s. сильная корреляция считаем abs(corr_coef) >= 0.7

# %% [markdown]
# Самые сильные связи видно у оценок в разные периоды времени, а-ля кто начал за упокой, тот и закончил за упокой, а кто начал за победу, тот и вышел победителем (кто хорошо начал тот хорошо и закончил)
# Также те, кто пьют в будни, тоже пьет и в выходные, а много неудач в начале дают высокий рост неудач в конце
